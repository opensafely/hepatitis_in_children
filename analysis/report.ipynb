# %% [markdown]
# ## Increase in hepatitis cases in children: a rapid OpenSAFELY analysis to support the national incident response
#
# Since January 2022, there have been 74 reported cases of hepatitis in children in the UK in which the common viruses that cause hepatitis have not been detected, but links to SARS-CoV-2 infection are being investigated. UKHSA have initiated a [national incident](https://www.gov.uk/government/news/increase-in-hepatitis-liver-inflammation-cases-in-children-under-investigation) and alerted the public to be on the lookout for signs and symptoms in children.
#
# The aim of this report is to describe the use OpenSAFELY to provide contextual information on children presenting in general practice for symptoms such as gastrointestinal illness and tests that GPs may order (e.g. liver functions) to diagnose hepatitis to inform the response and any investigations.

# %% [markdown]
# <ul id="docNav">
#
# <li> <a href="#hepatitis">Hepatitis</a>
#     <ul>
#        <li> <a href="#hepatitis_rate">Rate of recorded hepatitis</a>
#        <li> <a href="#hepatitis_rate_week">Rate of recorded hepatitis (weekly)</a>
#        <li> <a href="#hepatitis_decile">Practice level variation of recorded hepatitis</a>
#     </ul>
# <li> <a href="#gi_illness">Gastrointestinal illness</a>
#     <ul>
#        <li> <a href="#gi_illness_rate">Rate of recorded gastrointestinal illness</a>
#        <li> <a href="#gi_illness_rate_week">Rate of recorded gastrointestinal illness (weekly)</a>
#        <li> <a href="#gi_illness_decile">Practice level variation of recorded gastrointestinal illness</a>
#     </ul>
# <li> <a href="#alt">ALT tests</a>
#     <ul>
#        <li> <a href="#alt_rate_age">Rate of recorded ALT tests by age band</a>
#        <li> <a href="#alt_rate_week">Rate of recorded ALT tests (weekly)</a>
#        <li> <a href="#alt_decile">Practice level variation of recorded ALT tests</a>
#        <li> <a href="#alt_oor">Count of recorded ALT tests out of range</a>
#        <li> <a href="#alt_cov">Count of recorded ALT tests out of range by recent positive COVID-19 test</a>
#     </ul>
# <li> <a href="#ast">AST tests</a>
#     <ul>
#        <li> <a href="#ast_rate_age">Rate of recorded AST tests by age band</a>
#        <li> <a href="#ast_rate_week">Rate of recorded AST tests (weekly)</a>
#        <li> <a href="#ast_decile">Practice level variation of recorded AST tests</a>
#        <li> <a href="#ast_oor">Count of recorded AST tests out of range</a>
#        <li> <a href="#ast_cov">Count of recorded AST tests out of range by recent positive COVID-19 test</a>
#     </ul>
# <li> <a href="#bilirubin">Bilirubin tests</a>
#     <ul>
#        <li> <a href="#bilirubin_rate_age">Rate of recorded bilirubin tests by age band</a>
#        <li> <a href="#bilirubin_rate_week">Rate of recorded bilirubin tests (weekly)</a>
#        <li> <a href="#bilirubin_decile">Practice level variation of recorded bilirubin tests</a>
#        <li> <a href="#bilirubin_oor">Count of recorded bilirubin tests out of range</a>
#        <li> <a href="#bilirubin_cov">Count of recorded bilirubin tests out of range by recent positive COVID-19 test</a>
#     </ul>
# </ul>

# %%
from IPython.display import Image, Markdown
import json

practice_counts = {}
for frequency in ["monthly", "weekly"]:
    for test in ["alt", "ast", "bilirubin", "gi_illness", "hepatitis"]:
        with open(f"../output/{frequency}/joined/practice_count_{test}.json") as f:
            practice_counts[f"{frequency}_{test}"] = json.load(f)["num_practices"]

# %% [markdown]
# <a id="hepatitis"></a>
# ### Hepatitis
#
# [CODELIST](https://www.opencodelists.org/codelist/user/brian-mackenna/inflammatory-disease-of-the-liver/52b972ae/)

# %%
Image(filename="../output/monthly/joined/plot_hepatitis.png")

# %% [markdown]
# **Rate of recorded hepatitis per 1000 registered patients each month between 2017-04-01 and 2022-04-01.**

# %%
Image(filename="../output/weekly/joined/plot_hepatitis.png")

# %% [markdown]
# **Rate of recorded hepatitis per 1000 registered patients each week between 2021-04-01 and 2022-03-31.**

# %%
display(
    Markdown(f"Number of practices included: {practice_counts[f'weekly_hepatitis']['num_practices_included']} / {practice_counts[f'weekly_hepatitis']['num_practices']}")
    )
# Out:
# Number of practices included: 40 / 41

# %%
Image(filename="../output/monthly/joined/deciles_chart_hepatitis.png")

# %% [markdown]
# **Practice level decile chart of the rate per 1000 registered patients with a record of hepatitis each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="gi_illness"></a>
# ### Gastrointestinal illness
#
# [CODELIST](https://www.opencodelists.org/codelist/user/kate-mansfield/disorder-of-digestive-system-all-descendants/189e8759/#full-list)

# %% [markdown]
# <a id="gi_illness_rate"></a>

# %%
Image(filename="../output/monthly/joined/plot_gi_illness.png")

# %% [markdown]
# **Rate of recorded gastrointestinal illness per 1000 registered patients each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="gi_illness_rate_week"></a>

# %%
Image(filename="../output/weekly/joined/plot_gi_illness.png")

# %% [markdown]
# **Rate of recorded gastrointestinal illness per 1000 registered patients each week between 2021-04-01 and 2022-03-31.**

# %%
display(
    Markdown(f"Number of practices included: {practice_counts[f'weekly_gi_illness']['num_practices_included']} / {practice_counts[f'weekly_gi_illness']['num_practices']}")
    )

# %% [markdown]
# <a id="gi_illness_decile"></a>

# %%
Image(filename="../output/monthly/joined/deciles_chart_gi_illness.png")

# %% [markdown]
# **Practice level decile chart of the rate per 1000 registered patients with a record of gastrointestinal illness each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="alt"></a>
# ### Alanine aminotransferase (ALT) tests
#
# [CODELIST](https://www.opencodelists.org/codelist/opensafely/alanine-aminotransferase-alt-tests/2298df3e/#full-list)

# %% [markdown]
# <a id="alt_rate_age"></a>

# %%
Image(filename="../output/monthly/joined/plot_alt_age_band_months.png")

# %% [markdown]
# **Rate of recorded ALT tests per 1000 registered patients by age band each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="alt_rate_week"></a>

# %%
Image(filename="../output/weekly/joined/plot_alt.png")

# %% [markdown]
# **Rate of recorded ALT test per 1000 registered patients each week between 2021-04-01 and 2022-03-31.**

# %%
display(
    Markdown(f"Number of practices included: {practice_counts[f'weekly_alt']['num_practices_included']} / {practice_counts[f'weekly_alt']['num_practices']}")
    )

# %% [markdown]
# <a id="alt_rate_decile"></a>

# %%
Image(filename="../output/monthly/joined/deciles_chart_alt.png")

# %% [markdown]
# **Practice level decile chart of the rate of ALT tests per 1000 registered patients each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="alt_oor"></a>

# %%
Image(filename="../output/weekly/joined/plot_alt_oor_count.png")

# %% [markdown]
# **Count of recorded ALT tests >500 U/L in registered patients with a record of an ALT test each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="alt_cov"></a>

# %%
Image(filename="../output/weekly/joined/plot_alt_oor_recent_cov_count.png")

# %% [markdown]
# **Count of recorded ALT tests >500 U/L in registered patients with a record of an ALT test each month between 2021-04-01 and 2022-03-31 broken down by recent positive COVID-19 test (within 3 months)**

# %% [markdown]
# <a id="ast"></a>
# ### Aspartate aminotransferase (AST) tests
#
# [CODELIST](https://www.opencodelists.org/codelist/user/Louis/aspartate-aminotransferase/30cb0c08/#full-list)

# %% [markdown]
# <a id="ast_rate_age"></a>

# %%
Image(filename="../output/monthly/joined/plot_ast_age_band_months.png")

# %% [markdown]
# **Rate of recorded AST tests per 1000 registered patients by age band each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="ast_rate_week"></a>

# %%
Image(filename="../output/weekly/joined/plot_ast.png")

# %% [markdown]
# **Rate per 1000 registered patients with a record of an AST test each week between 2021-04-01 and 2022-03-31.**

# %%
display(
    Markdown(f"Number of practices included: {practice_counts[f'weekly_ast']['num_practices_included']} / {practice_counts[f'weekly_ast']['num_practices']}")
    )
# Out:
# Number of practices included: 40 / 41

# %% [markdown]
# <a id="ast_rate_decile"></a>

# %%
Image(filename="../output/monthly/joined/deciles_chart_ast.png")

# %% [markdown]
# **Practice level decile chart of the rate per 1000 registered patients with a record of an AST test each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="ast_oor"></a>

# %%
Image(filename="../output/weekly/joined/plot_ast_oor_count.png")

# %% [markdown]
# **Count of recorded AST tests >500 U/L in registered patients with a record of an AST test each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="ast_cov"></a>

# %%
Image(filename="../output/weekly/joined/plot_ast_oor_recent_cov_count.png")

# %% [markdown]
# **Count of recorded AST tests >500 U/L in registered patients with a record of an AST test each month between 2017-04-01 and 2022-04-01 broken down by recent positive COVID-19 test (within 3 months)**

# %% [markdown]
# <a id="bilirubin"></a>
# ### Bilirubin tests
#
# [CODELIST](https://www.opencodelists.org/codelist/user/Louis/bilirubin-tests/17bb98d3/#full-list)

# %% [markdown]
# <a id="bilirubin_rate_age"></a>

# %%
Image(filename="../output/monthly/joined/plot_bilirubin_age_band_months.png")

# %% [markdown]
# **Rate of recorded bilirubin tests per 1000 registered patients by age band each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="bilirubin_rate_week"></a>

# %%
Image(filename="../output/weekly/joined/plot_bilirubin.png")

# %% [markdown]
# **Rate per 1000 registered patients with a record of a bilirubin test each week between 2021-04-01 and 2022-03-31.**

# %%
display(
    Markdown(f"Number of practices included: {practice_counts[f'weekly_bilirubin']['num_practices_included']} / {practice_counts[f'weekly_bilirubin']['num_practices']}")
    )
# Out:
# Number of practices included: 40 / 41

# %% [markdown]
# <a id="bilirubin_decile"></a>

# %%
Image(filename="../output/monthly/joined/deciles_chart_bilirubin.png")

# %% [markdown]
# **Practice level decile chart of the rate per 1000 registered patients with a record of a bilirubin test each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="bilirubin_oor"></a>

# %%
Image(filename="../output/weekly/joined/plot_bilirubin_oor_count.png")

# %% [markdown]
# **Count of recorded bilirubin tests > upper reference range in registered patients with a record of an bilirubin test each month between 2017-04-01 and 2022-04-01.**

# %% [markdown]
# <a id="bilirubin_cov"></a>

# %%
Image(filename="../output/weekly/joined/plot_bilirubin_oor_recent_cov_count.png")

# %% [markdown]
# **Count of recorded bilirubin tests > reference range in registered patients with a record of an bilirubin test each month between 2017-04-01 and 2022-04-01 broken down by recent positive COVID-19 test (within 3 months)**
